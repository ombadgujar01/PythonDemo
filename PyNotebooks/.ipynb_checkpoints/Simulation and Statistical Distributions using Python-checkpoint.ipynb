# %% [markdown]
# # Simulation and Statistical Distributions using Python
#
# **Tools:** NumPy, Pandas, SciPy, Matplotlib
#
# ### Instructions
# - Answer all questions using Python.
# - Clearly label all plots.
# - Briefly interpret results wherever asked.

# %%
# Core libraries (already available in Colab)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Plot settings
plt.style.use("default")
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# ## Question 1: Normal Distribution and Sample Size
#
# Generate random samples from a Normal distribution with mean $\mu$ and standard
# deviation $\sigma$ using `numpy.random.normal` for the following sample sizes: $n = 10,\; 50,\; 500,\; 5000$
# 1. Compute the sample mean and sample standard deviation for each sample.
# 2. Plot histograms using identical bins for all sample sizes.
# 3. Superimpose the theoretical PDF using `scipy.stats.norm.pdf`.
# 4. Comment on the effect of sample size on the shape of the distribution and
#    parameter estimates.

# %% [markdown]
# ## Question 2: Exponential Distribution and Memoryless Property
#
# Generate a random sample of size 10,000 from an Exponential distribution using
# `numpy.random.exponential`.
# 1. Estimate the rate parameter using the sample mean.
# 2. Empirically verify the memoryless property $P(X > s+t \mid X > s) = P(X > t)$.
# 3. Compare empirical probabilities with theoretical values obtained using `scipy.stats.expon`.

# %% [markdown]
# ## Question 3: Binomial and Poisson Distributions
#
# Generate random samples from:
# - Binomial$(n, p)$ distribution
# - Poisson$(\lambda = np)$ distribution
#
# Use two different choices of $(n, p)$.
# 1. Plot empirical PMFs and overlay theoretical PMFs.
# 2. Compare the distributions numerically and graphically.
# 3. Comment on the validity of the Poisson approximation.

# %% [markdown]
# ## Question 4: Normal vs Cauchy Distribution
#
# Generate random samples from:
# - Normal distribution
# - Cauchy distribution
#
# for increasing sample sizes.
#
# 1. Compute the sample mean and sample median for each sample.
# 2. Plot these statistics as functions of sample size.
# 3. Comment on the stability of the estimators.

# %% [markdown]
# ## Question 5: Gamma Distribution – Parameter Estimation
#
# Generate a random sample from a Gamma distribution using `numpy.random.gamma`.
#
# 1. Estimate the parameters using the method of moments.
# 2. Estimate the parameters using quantiles obtained via `scipy.stats.gamma.ppf`.
# 3. Compare the estimates and comment on their sensitivity.

# %% [markdown]
# ## Question 6: Discrete Distributions and Support
#
# Generate random samples from the following distributions:
# - Binomial
# - Geometric
# - Negative Binomial
#
# 1. Plot empirical PMFs and overlay theoretical PMFs.
# 2. Identify the support of each distribution.
# 3. Comment on differences in interpretation of the random variable.
